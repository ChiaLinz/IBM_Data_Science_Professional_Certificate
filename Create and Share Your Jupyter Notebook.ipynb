# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Objective:
#
# In this final assignment, you will be able to learn:
#
# * Creating a Jupyter Notebook using Skills Network LTI item or Watson Studio environment.
#
# * Create Markdown cells.

# %% [markdown]
# # Instructions
# Congratulations on finishing all three modules of this course. This week, you'll work on your final assignment which will be graded by your peers.
#
# This course introduced you to multiple data science tools, and in this final project, you will use Jupyter Notebook, one of the easiest tools to share publicly.
#
# Include at least 6 cells:
# * <strong>Cell 1 (rendered as Markdown)</strong>: The title should be "My Jupyter Notebook on IBM Watson Studio", in H1 header styling. The title does not need to be centered.
#
# * <strong>Cell 2 (rendered as Markdown)</strong>: Include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font.
#
# * <strong>Cell 3 (rendered as Markdown)</strong>: In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ...".
#
# * <strong>Cell 4 (rendered as Markdown)</strong>: In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5.
#
# * <strong>Cell 5 (code cell)</strong>: Your code, as described in Cell 4. It must be executed and must display an output. Try to keep the code simple (it can even be "1 + 1").
#
# * <strong>Cell 6 (rendered as Markdown)</strong>: Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.

# %% [markdown]
# - --

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <strong>Chia-Lin Hsieh</strong>

# %% [markdown]
# Data Scientist / Data Analyst

# %% [markdown]
# *I am highly interested in the field of data science, and my passion for this discipline has grown exponentially over the years. My interest in data science was sparked when I started studying Statistics and Information Science for my bachelor's degree, which gave me a solid foundation in data analysis and statistical modeling. This fascination deepened further as I pursued my Master's in Data Science, where I had the opportunity to work on various data-driven projects, such as developing a power outage prediction system and creating an autonomous game agent using Reinforcement Learning. These experiences have taught me how to use data to uncover insights, make informed decisions, and solve complex problems. My proficiency in programming languages such as Python, SQL, R, Java, and JavaScript, as well as my experience in using frameworks and tools such as Power BI, Tableau, and TensorFlow, has further reinforced my interest in data science. I am excited about the endless possibilities that data science offers, and I am eager to continue exploring the field, learning new techniques, and leveraging data to drive innovation and change.*

# %% [markdown]
# ### The following code is using random to generate 100 values, and using Matplotlib to draw a graph.

# %%
import random
import matplotlib.pyplot as plt

nums = []
mu = 100
sigma = 50

for i in range(100):
    temp = random.gauss(mu, sigma)
    nums.append(temp)

# plotting a graph
plt.plot(nums)
plt.show()

# %% [markdown]
# * <strong>Cell 1 (rendered as Markdown)</strong>: The title should be "My Jupyter Notebook on IBM Watson Studio", in H1 header styling. The title does not need to be centered.
#
# * <strong>Cell 2 (rendered as Markdown)</strong>: Include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font.
#
# * <strong>Cell 3 (rendered as Markdown)</strong>: In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ...".
#
# * <strong>Cell 4 (rendered as Markdown)</strong>: In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5.
#
# * <strong>Cell 5 (code cell)</strong>: Your code, as described in Cell 4. It must be executed and must display an output. Try to keep the code simple (it can even be "1 + 1").
#
# * <strong>Cell 6 (rendered as Markdown)</strong>: Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
#
# [My GitHub Link](https://github.com/ChiaLinz)
#
# -- -
#
# [Sample Result]
#
# ![Sample Result](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/FinalModule_Coursera/images/Final-5.png "a title")
